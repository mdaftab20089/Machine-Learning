# %% [markdown]
# ## Matplotlib Basics

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
x=np.arange(0,10)
y=np.arange(23,33)
a=np.arange(40,50)
b=np.arange(60,70)

plt.scatter(x,y,c='r')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('2D - Graph')
plt.plot(x,y,'r*-')
